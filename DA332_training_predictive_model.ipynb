# %%
import numpy as np
import pandas as pd
import os

# %%
base = '/Users/user/Desktop/DA332_course_project_weather_visualization/data'

# %%
india_files = os.listdir(base)

# %%
india_files
# Out:
# ['Thane_weather.csv',
#  'Hyderabad_weather.csv',
#  'Panaji_weather.csv',
#  'Itanagar_weather.csv',
#  'Raipur_weather.csv',
#  'Chennai_weather.csv',
#  'Bhubaneswar_weather.csv',
#  'Vadodara_weather.csv',
#  'Lucknow_weather.csv',
#  'Patna_weather.csv',
#  'world_cities_map.csv',
#  'Surat_weather.csv',
#  'Pune_weather.csv',
#  'Thiruvananthapuram_weather.csv',
#  'Dehradun_weather.csv',
#  'Kolkata_weather.csv',
#  'Visakhapatnam_weather.csv',
#  'world_cities_lat_long.csv',
#  'Kohima_weather.csv',
#  'Shillong_weather.csv',
#  'Ghaziabad_weather.csv',
#  'Bengaluru_weather.csv',
#  'Aizawl_weather.csv',
#  'Ahmedabad_weather.csv',
#  'Indore_weather.csv',
#  'Guwahati_weather.csv',
#  'Chandigarh_weather.csv',
#  'Agartala_weather.csv',
#  'Ranchi_weather.csv',
#  'Imphal_weather.csv',
#  'Kanpur_weather.csv',
#  'Shimla_weather.csv',
#  'Bhopal_weather.csv',
#  'Delhi_weather.csv',
#  'Mumbai_weather.csv',
#  'Jaipur_weather.csv',
#  'Gangtok_weather.csv',
#  'Nagpur_weather.csv',
#  'region_month_stats.csv']

# %%
df1 = pd.read_csv(f'{base}/Delhi_weather.csv')

# %%
df1.head()
# Out:
#          Date  Max Temperature (°C)  Min Temperature (°C)  \
# 0  2015-01-01                  21.1                  11.8
# 1  2015-01-02                  16.9                  14.0
# 2  2015-01-03                  17.7                  13.7
# 3  2015-01-04                  18.8                  10.7
# 4  2015-01-05                  20.4                   9.4
#
#    Total Rainfall (mm) Sunrise Time Sunset Time Daylight Duration  \
# 0                  0.0     07:14:00    17:35:00          10:21:05
# 1                  3.4     07:14:00    17:35:00          10:21:31
# 2                  0.5     07:14:00    17:36:00          10:22:00
# 3                  0.0     07:14:00    17:37:00          10:22:31
# 4                  0.0     07:14:00    17:37:00          10:23:05
#
#    Precipitation Hours  Max Wind Speed (m/s)  Max UV Index
# 0                  0.0                   9.4           NaN
# 1                  7.0                   9.7           NaN
# 2                  2.0                   8.9           NaN
# 3                  0.0                  13.4           NaN
# 4                  0.0                  27.4           NaN

# %%
files_weather_data = [file for file in india_files if '_weather' in file]

# %%
files_weather_data
# Out:
# ['Thane_weather.csv',
#  'Hyderabad_weather.csv',
#  'Panaji_weather.csv',
#  'Itanagar_weather.csv',
#  'Raipur_weather.csv',
#  'Chennai_weather.csv',
#  'Bhubaneswar_weather.csv',
#  'Vadodara_weather.csv',
#  'Lucknow_weather.csv',
#  'Patna_weather.csv',
#  'Surat_weather.csv',
#  'Pune_weather.csv',
#  'Thiruvananthapuram_weather.csv',
#  'Dehradun_weather.csv',
#  'Kolkata_weather.csv',
#  'Visakhapatnam_weather.csv',
#  'Kohima_weather.csv',
#  'Shillong_weather.csv',
#  'Ghaziabad_weather.csv',
#  'Bengaluru_weather.csv',
#  'Aizawl_weather.csv',
#  'Ahmedabad_weather.csv',
#  'Indore_weather.csv',
#  'Guwahati_weather.csv',
#  'Chandigarh_weather.csv',
#  'Agartala_weather.csv',
#  'Ranchi_weather.csv',
#  'Imphal_weather.csv',
#  'Kanpur_weather.csv',
#  'Shimla_weather.csv',
#  'Bhopal_weather.csv',
#  'Delhi_weather.csv',
#  'Mumbai_weather.csv',
#  'Jaipur_weather.csv',
#  'Gangtok_weather.csv',
#  'Nagpur_weather.csv']

# %%
dfs = []
for file in files_weather_data:
    dfs.append(pd.read_csv(f'{base}/{file}'))

# %%
df = pd.concat(dfs)

# %%
df
# Out:
#             Date  Max Temperature (°C)  Min Temperature (°C)  \
# 0     2015-01-01                  26.8                  18.4
# 1     2015-01-02                  27.0                  18.0
# 2     2015-01-03                  28.5                  18.6
# 3     2015-01-04                  30.9                  18.5
# 4     2015-01-05                  31.1                  19.8
# ...          ...                   ...                   ...
# 3648  2024-12-27                  29.0                  19.3
# 3649  2024-12-28                  29.5                  19.9
# 3650  2024-12-29                  28.0                  18.5
# 3651  2024-12-30                  29.3                  18.8
# 3652  2024-12-31                  29.5                  17.7
#
#       Total Rainfall (mm) Sunrise Time Sunset Time Daylight Duration  \
# 0                     0.1     07:11:00    18:11:00          10:59:34
# 1                     0.0     07:11:00    18:11:00          10:59:50
# 2                     0.0     07:12:00    18:12:00          11:00:08
# 3                     0.0     07:12:00    18:12:00          11:00:28
# 4                     0.0     07:12:00    18:13:00          11:00:49
# ...                   ...          ...         ...               ...
# 3648                  0.6     06:49:00    17:40:00          10:51:17
# 3649                  1.6     06:49:00    17:40:00          10:51:28
# 3650                  0.7     06:49:00    17:41:00          10:51:41
# 3651                  0.0     06:50:00    17:42:00          10:51:55
# 3652                  0.0     06:50:00    17:42:00          10:52:11
#
#       Precipitation Hours  Max Wind Speed (m/s)  Max UV Index
# 0                     1.0                  10.9           NaN
# 1                     0.0                   8.5           NaN
# 2                     0.0                  10.1           NaN
# 3                     0.0                  11.9           NaN
# 4                     0.0                  12.5           NaN
# ...                   ...                   ...           ...
# 3648                  4.0                  11.6           NaN
# 3649                  5.0                  12.7           NaN
# 3650                  3.0                   9.0           NaN
# 3651                  0.0                   9.6           NaN
# 3652                  0.0                  10.9           NaN
#
# [131508 rows x 10 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['day_of_year'] = df['Date'].dt.dayofyear

df['sin_day'] = np.sin(2 * np.pi * df['day_of_year'] / 365)
df['cos_day'] = np.cos(2 * np.pi * df['day_of_year'] / 365)

# %%
df
# Out:
#            Date  Max Temperature (°C)  Min Temperature (°C)  \
# 0    2015-01-01                  26.8                  18.4
# 1    2015-01-02                  27.0                  18.0
# 2    2015-01-03                  28.5                  18.6
# 3    2015-01-04                  30.9                  18.5
# 4    2015-01-05                  31.1                  19.8
# ...         ...                   ...                   ...
# 3648 2024-12-27                  29.0                  19.3
# 3649 2024-12-28                  29.5                  19.9
# 3650 2024-12-29                  28.0                  18.5
# 3651 2024-12-30                  29.3                  18.8
# 3652 2024-12-31                  29.5                  17.7
#
#       Total Rainfall (mm) Sunrise Time Sunset Time Daylight Duration  \
# 0                     0.1     07:11:00    18:11:00          10:59:34
# 1                     0.0     07:11:00    18:11:00          10:59:50
# 2                     0.0     07:12:00    18:12:00          11:00:08
# 3                     0.0     07:12:00    18:12:00          11:00:28
# 4                     0.0     07:12:00    18:13:00          11:00:49
# ...                   ...          ...         ...               ...
# 3648                  0.6     06:49:00    17:40:00          10:51:17
# 3649                  1.6     06:49:00    17:40:00          10:51:28
# 3650                  0.7     06:49:00    17:41:00          10:51:41
# 3651                  0.0     06:50:00    17:42:00          10:51:55
# 3652                  0.0     06:50:00    17:42:00          10:52:11
#
#       Precipitation Hours  Max Wind Speed (m/s)  Max UV Index  day_of_year  \
# 0                     1.0                  10.9           NaN            1
# 1                     0.0                   8.5           NaN            2
# 2                     0.0                  10.1           NaN            3
# 3                     0.0                  11.9           NaN            4
# 4                     0.0                  12.5           NaN            5
# ...                   ...                   ...           ...          ...
# 3648                  4.0                  11.6           NaN          362
# 3649                  5.0                  12.7           NaN          363
# 3650                  3.0                   9.0           NaN          364
# 3651                  0.0                   9.6           NaN          365
# 3652                  0.0                  10.9           NaN          366
#
#            sin_day   cos_day
# 0     1.721336e-02  0.999852
# 1     3.442161e-02  0.999407
# 2     5.161967e-02  0.998667
# 3     6.880243e-02  0.997630
# 4     8.596480e-02  0.996298
# ...            ...       ...
# 3648 -5.161967e-02  0.998667
# 3649 -3.442161e-02  0.999407
# 3650 -1.721336e-02  0.999852
# 3651  6.432491e-16  1.000000
# 3652  1.721336e-02  0.999852
#
# [131508 rows x 13 columns]

# %%
cols = df.columns

# %%
cols
# Out:
# Index(['Date', 'Max Temperature (°C)', 'Min Temperature (°C)',
#        'Total Rainfall (mm)', 'Sunrise Time', 'Sunset Time',
#        'Daylight Duration', 'Precipitation Hours', 'Max Wind Speed (m/s)',
#        'Max UV Index', 'day_of_year', 'sin_day', 'cos_day'],
#       dtype='object')

# %%
columns_to_keep = ['Max Temperature (°C)', 'Min Temperature (°C)',
       'Total Rainfall (mm)', 'Precipitation Hours', 'Max Wind Speed (m/s)',
       'sin_day', 'cos_day']

# %%
df_t = df[columns_to_keep]

# %%
df_t
# Out:
#       Max Temperature (°C)  Min Temperature (°C)  Total Rainfall (mm)  \
# 0                     26.8                  18.4                  0.1
# 1                     27.0                  18.0                  0.0
# 2                     28.5                  18.6                  0.0
# 3                     30.9                  18.5                  0.0
# 4                     31.1                  19.8                  0.0
# ...                    ...                   ...                  ...
# 3648                  29.0                  19.3                  0.6
# 3649                  29.5                  19.9                  1.6
# 3650                  28.0                  18.5                  0.7
# 3651                  29.3                  18.8                  0.0
# 3652                  29.5                  17.7                  0.0
#
#       Precipitation Hours  Max Wind Speed (m/s)       sin_day   cos_day
# 0                     1.0                  10.9  1.721336e-02  0.999852
# 1                     0.0                   8.5  3.442161e-02  0.999407
# 2                     0.0                  10.1  5.161967e-02  0.998667
# 3                     0.0                  11.9  6.880243e-02  0.997630
# 4                     0.0                  12.5  8.596480e-02  0.996298
# ...                   ...                   ...           ...       ...
# 3648                  4.0                  11.6 -5.161967e-02  0.998667
# 3649                  5.0                  12.7 -3.442161e-02  0.999407
# 3650                  3.0                   9.0 -1.721336e-02  0.999852
# 3651                  0.0                   9.6  6.432491e-16  1.000000
# 3652                  0.0                  10.9  1.721336e-02  0.999852
#
# [131508 rows x 7 columns]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Clip rainfall values above 50 mm
rainfall_clipped = df_t['Total Rainfall (mm)'].clip(upper=50)

# Define 5 mm bin edges
bin_edges = np.arange(0, 55, 5)  # from 0 to 50 inclusive

plt.figure(figsize=(10, 6))
sns.histplot(
    x=rainfall_clipped,
    bins=bin_edges,
    kde=True,
    color='skyblue',
    edgecolor='black'
)

plt.title('Histogram + KDE of Total Rainfall (Clipped at 50 mm, 5 mm bins)')
plt.xlabel('Total Rainfall (mm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def rainfall_category(rainfall):
    if rainfall == 0:
        return 1  # No rain
    elif rainfall <= 7.5:
        return 2  # Light rain
    elif rainfall <= 36:
        return 3  # Moderate rain
    else:
        return 4  # Heavy rain

# %%
lag_cols = [
    'Max Temperature (°C)',
    'Min Temperature (°C)',
    'Total Rainfall (mm)',
    'Max Wind Speed (m/s)'
]

for col in lag_cols:
    for lag in range(1, 8):  # 1 to 7 days ago
        df_t[f'{col}_lag{lag}'] = df_t[col].shift(lag)

df_model = df_t.dropna().copy()

target_cols = lag_cols
feature_cols = [f'{col}_lag{lag}' for col in lag_cols for lag in range(1, 8)] + ['sin_day', 'cos_day']

X = df_model[feature_cols]
y = df_model[target_cols]
# Out:
# /var/folders/xn/ll477s2d7y1c7rpqqgg1swsr0000gn/T/ipykernel_4427/1868483570.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t[f'{col}_lag{lag}'] = df_t[col].shift(lag)

# %%
X
# Out:
#       Max Temperature (°C)_lag1  Max Temperature (°C)_lag2  \
# 7                          30.1                       31.1
# 8                          31.1                       30.1
# 9                          31.4                       31.1
# 10                         31.3                       31.4
# 11                         31.7                       31.3
# ...                         ...                        ...
# 3648                       28.5                       28.7
# 3649                       29.0                       28.5
# 3650                       29.5                       29.0
# 3651                       28.0                       29.5
# 3652                       29.3                       28.0
#
#       Max Temperature (°C)_lag3  Max Temperature (°C)_lag4  \
# 7                          31.1                       30.9
# 8                          31.1                       31.1
# 9                          30.1                       31.1
# 10                         31.1                       30.1
# 11                         31.4                       31.1
# ...                         ...                        ...
# 3648                       28.8                       28.9
# 3649                       28.7                       28.8
# 3650                       28.5                       28.7
# 3651                       29.0                       28.5
# 3652                       29.5                       29.0
#
#       Max Temperature (°C)_lag5  Max Temperature (°C)_lag6  \
# 7                          28.5                       27.0
# 8                          30.9                       28.5
# 9                          31.1                       30.9
# 10                         31.1                       31.1
# 11                         30.1                       31.1
# ...                         ...                        ...
# 3648                       28.4                       29.7
# 3649                       28.9                       28.4
# 3650                       28.8                       28.9
# 3651                       28.7                       28.8
# 3652                       28.5                       28.7
#
#       Max Temperature (°C)_lag7  Min Temperature (°C)_lag1  \
# 7                          26.8                       16.7
# 8                          27.0                       15.3
# 9                          28.5                       17.4
# 10                         30.9                       15.6
# 11                         31.1                       14.4
# ...                         ...                        ...
# 3648                       29.7                       18.8
# 3649                       29.7                       19.3
# 3650                       28.4                       19.9
# 3651                       28.9                       18.5
# 3652                       28.8                       18.8
#
#       Min Temperature (°C)_lag2  Min Temperature (°C)_lag3  ...  \
# 7                          18.2                       19.8  ...
# 8                          16.7                       18.2  ...
# 9                          15.3                       16.7  ...
# 10                         17.4                       15.3  ...
# 11                         15.6                       17.4  ...
# ...                         ...                        ...  ...
# 3648                       19.1                       18.3  ...
# 3649                       18.8                       19.1  ...
# 3650                       19.3                       18.8  ...
# 3651                       19.9                       19.3  ...
# 3652                       18.5                       19.9  ...
#
#       Total Rainfall (mm)_lag7  Max Wind Speed (m/s)_lag1  \
# 7                          0.1                       12.2
# 8                          0.0                       12.5
# 9                          0.0                       11.9
# 10                         0.0                       12.5
# 11                         0.0                       12.6
# ...                        ...                        ...
# 3648                       0.0                       10.1
# 3649                       0.0                       11.6
# 3650                       0.0                       12.7
# 3651                       0.0                        9.0
# 3652                       0.0                        9.6
#
#       Max Wind Speed (m/s)_lag2  Max Wind Speed (m/s)_lag3  \
# 7                          12.4                       12.5
# 8                          12.2                       12.4
# 9                          12.5                       12.2
# 10                         11.9                       12.5
# 11                         12.5                       11.9
# ...                         ...                        ...
# 3648                       12.7                       10.1
# 3649                       10.1                       12.7
# 3650                       11.6                       10.1
# 3651                       12.7                       11.6
# 3652                        9.0                       12.7
#
#       Max Wind Speed (m/s)_lag4  Max Wind Speed (m/s)_lag5  \
# 7                          11.9                       10.1
# 8                          12.5                       11.9
# 9                          12.4                       12.5
# 10                         12.2                       12.4
# 11                         12.5                       12.2
# ...                         ...                        ...
# 3648                       13.2                        9.3
# 3649                       10.1                       13.2
# 3650                       12.7                       10.1
# 3651                       10.1                       12.7
# 3652                       11.6                       10.1
#
#       Max Wind Speed (m/s)_lag6  Max Wind Speed (m/s)_lag7  sin_day  cos_day
# 7                           8.5                       10.9  1.4e-01      1.0
# 8                          10.1                        8.5  1.5e-01      1.0
# 9                          11.9                       10.1  1.7e-01      1.0
# 10                         12.5                       11.9  1.9e-01      1.0
# 11                         12.4                       12.5  2.1e-01      1.0
# ...                         ...                        ...      ...      ...
# 3648                       12.5                        9.6 -5.2e-02      1.0
# 3649                        9.3                       12.5 -3.4e-02      1.0
# 3650                       13.2                        9.3 -1.7e-02      1.0
# 3651                       10.1                       13.2  6.4e-16      1.0
# 3652                       12.7                       10.1  1.7e-02      1.0
#
# [131501 rows x 30 columns]

# %%
y
# Out:
#       Max Temperature (°C)  Min Temperature (°C)  Total Rainfall (mm)  \
# 7                     31.1                  15.3                  0.0
# 8                     31.4                  17.4                  0.0
# 9                     31.3                  15.6                  0.0
# 10                    31.7                  14.4                  0.0
# 11                    31.2                  15.7                  0.0
# ...                    ...                   ...                  ...
# 3648                  29.0                  19.3                  0.6
# 3649                  29.5                  19.9                  1.6
# 3650                  28.0                  18.5                  0.7
# 3651                  29.3                  18.8                  0.0
# 3652                  29.5                  17.7                  0.0
#
#       Max Wind Speed (m/s)
# 7                     12.5
# 8                     11.9
# 9                     12.5
# 10                    12.6
# 11                    12.2
# ...                    ...
# 3648                  11.6
# 3649                  12.7
# 3650                   9.0
# 3651                   9.6
# 3652                  10.9
#
# [131501 rows x 4 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical


# Step 1: Extract and convert rainfall to categorical
def rainfall_category(rainfall):
    if rainfall == 0:
        return 0  
    elif rainfall <= 5:
        return 1  
    elif rainfall <= 20:
        return 2  
    else:
        return 3  

y_rain_cat = y['Total Rainfall (mm)'].apply(rainfall_category)
y_rain_cat = to_categorical(y_rain_cat, num_classes=4)  # One-hot encode

y_reg = y.drop(columns=['Total Rainfall (mm)'])

# Step 2: Train-test split
X_train, X_test, y_reg_train, y_reg_test, y_cat_train, y_cat_test = train_test_split(
    X, y_reg, y_rain_cat, test_size=0.2, random_state=42
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (105200, 30)

# %%
X_train['Total Rainfall (mm)_lag1']
# Out:
# 3505    3.3
# 2321    0.0
# 1361    0.4
# 1659    0.0
# 2616    0.0
#        ...
# 98      0.0
# 685     0.0
# 2990    0.0
# 1417    0.0
# 1416    0.0
# Name: Total Rainfall (mm)_lag1, Length: 105200, dtype: float64

# %%
y_reg_train.shape
# Out:
# (105200, 3)

# %%
y_cat_train.shape
# Out:
# (105200, 4)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

input_layer = Input(shape=(X.shape[1],))

# Shared base
x = Dense(128, activation='relu')(input_layer)
x = Dense(64, activation='relu')(x)

reg_output = Dense(3, name='regression')(x)

class_output = Dense(4, activation='softmax', name='classification')(x)

# Define model
model = Model(inputs=input_layer, outputs=[reg_output, class_output])

model.compile(
    optimizer='adam',
    loss={'regression': 'mse', 'classification': 'categorical_crossentropy'},
    metrics={'regression': 'mae', 'classification': 'accuracy'}
)

model.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, 30)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 128)       │      3,968 │ input_layer_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 64)        │      8,256 │ dense_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ regression (Dense)  │ (None, 3)         │        195 │ dense_23[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification      │ (None, 4)         │        260 │ dense_23[0][0]    │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 12,679 (49.53 KB)
#  Trainable params: 12,679 (49.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train_scaled,
    {'regression': y_reg_train, 'classification': y_cat_train},
    validation_data=(X_test_scaled, {'regression': y_reg_test, 'classification': y_cat_test}),
    epochs=40,
    batch_size=32
)
# Out:
# Epoch 1/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 513us/step - classification_accuracy: 0.6131 - classification_loss: 0.8991 - loss: 43.5515 - regression_loss: 42.6524 - regression_mae: 3.7300 - val_classification_accuracy: 0.6764 - val_classification_loss: 0.7564 - val_loss: 5.5081 - val_regression_loss: 4.7515 - val_regression_mae: 1.4564
# Epoch 2/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 493us/step - classification_accuracy: 0.6771 - classification_loss: 0.7513 - loss: 5.4416 - regression_loss: 4.6903 - regression_mae: 1.4441 - val_classification_accuracy: 0.6764 - val_classification_loss: 0.7522 - val_loss: 5.4930 - val_regression_loss: 4.7407 - val_regression_mae: 1.4431
# Epoch 3/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 490us/step - classification_accuracy: 0.6906 - classification_loss: 0.7289 - loss: 5.3348 - regression_loss: 4.6060 - regression_mae: 1.4160 - val_classification_accuracy: 0.6857 - val_classification_loss: 0.7374 - val_loss: 5.2813 - val_regression_loss: 4.5437 - val_regression_mae: 1.3968
# Epoch 4/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 505us/step - classification_accuracy: 0.6924 - classification_loss: 0.7211 - loss: 5.2662 - regression_loss: 4.5451 - regression_mae: 1.4074 - val_classification_accuracy: 0.6909 - val_classification_loss: 0.7284 - val_loss: 5.2723 - val_regression_loss: 4.5437 - val_regression_mae: 1.4159
# Epoch 5/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 506us/step - classification_accuracy: 0.6938 - classification_loss: 0.7193 - loss: 5.2281 - regression_loss: 4.5088 - regression_mae: 1.4048 - val_classification_accuracy: 0.6910 - val_classification_loss: 0.7243 - val_loss: 5.3917 - val_regression_loss: 4.6673 - val_regression_mae: 1.4479
# Epoch 6/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 519us/step - classification_accuracy: 0.6939 - classification_loss: 0.7160 - loss: 5.1941 - regression_loss: 4.4782 - regression_mae: 1.3983 - val_classification_accuracy: 0.6858 - val_classification_loss: 0.7350 - val_loss: 5.3375 - val_regression_loss: 4.6023 - val_regression_mae: 1.4309
# Epoch 7/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 608us/step - classification_accuracy: 0.6981 - classification_loss: 0.7124 - loss: 5.1593 - regression_loss: 4.4469 - regression_mae: 1.3919 - val_classification_accuracy: 0.6892 - val_classification_loss: 0.7263 - val_loss: 5.2535 - val_regression_loss: 4.5270 - val_regression_mae: 1.4060
# Epoch 8/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 514us/step - classification_accuracy: 0.6944 - classification_loss: 0.7169 - loss: 5.2268 - regression_loss: 4.5099 - regression_mae: 1.3904 - val_classification_accuracy: 0.6935 - val_classification_loss: 0.7177 - val_loss: 5.4142 - val_regression_loss: 4.6963 - val_regression_mae: 1.4646
# Epoch 9/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 515us/step - classification_accuracy: 0.6942 - classification_loss: 0.7165 - loss: 5.2023 - regression_loss: 4.4859 - regression_mae: 1.3917 - val_classification_accuracy: 0.6854 - val_classification_loss: 0.7364 - val_loss: 5.2563 - val_regression_loss: 4.5198 - val_regression_mae: 1.4049
# Epoch 10/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 496us/step - classification_accuracy: 0.6974 - classification_loss: 0.7145 - loss: 5.1235 - regression_loss: 4.4090 - regression_mae: 1.3868 - val_classification_accuracy: 0.6945 - val_classification_loss: 0.7174 - val_loss: 5.1757 - val_regression_loss: 4.4582 - val_regression_mae: 1.3829
# Epoch 11/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 506us/step - classification_accuracy: 0.6971 - classification_loss: 0.7134 - loss: 5.1618 - regression_loss: 4.4483 - regression_mae: 1.3863 - val_classification_accuracy: 0.6933 - val_classification_loss: 0.7186 - val_loss: 5.1652 - val_regression_loss: 4.4464 - val_regression_mae: 1.3843
# Epoch 12/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 497us/step - classification_accuracy: 0.6979 - classification_loss: 0.7073 - loss: 5.0876 - regression_loss: 4.3803 - regression_mae: 1.3811 - val_classification_accuracy: 0.6915 - val_classification_loss: 0.7198 - val_loss: 5.2237 - val_regression_loss: 4.5037 - val_regression_mae: 1.3894
# Epoch 13/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 500us/step - classification_accuracy: 0.6966 - classification_loss: 0.7086 - loss: 5.1534 - regression_loss: 4.4448 - regression_mae: 1.3821 - val_classification_accuracy: 0.6900 - val_classification_loss: 0.7233 - val_loss: 5.1497 - val_regression_loss: 4.4262 - val_regression_mae: 1.3701
# Epoch 14/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 499us/step - classification_accuracy: 0.6942 - classification_loss: 0.7109 - loss: 5.1328 - regression_loss: 4.4219 - regression_mae: 1.3790 - val_classification_accuracy: 0.6881 - val_classification_loss: 0.7301 - val_loss: 5.1629 - val_regression_loss: 4.4326 - val_regression_mae: 1.3760
# Epoch 15/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 505us/step - classification_accuracy: 0.6978 - classification_loss: 0.7079 - loss: 5.1611 - regression_loss: 4.4531 - regression_mae: 1.3838 - val_classification_accuracy: 0.6958 - val_classification_loss: 0.7115 - val_loss: 5.1261 - val_regression_loss: 4.4144 - val_regression_mae: 1.3728
# Epoch 16/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 501us/step - classification_accuracy: 0.7016 - classification_loss: 0.7018 - loss: 5.0449 - regression_loss: 4.3430 - regression_mae: 1.3731 - val_classification_accuracy: 0.6946 - val_classification_loss: 0.7193 - val_loss: 5.1789 - val_regression_loss: 4.4594 - val_regression_mae: 1.3823
# Epoch 17/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 502us/step - classification_accuracy: 0.6997 - classification_loss: 0.7051 - loss: 5.0796 - regression_loss: 4.3745 - regression_mae: 1.3765 - val_classification_accuracy: 0.6953 - val_classification_loss: 0.7172 - val_loss: 5.2152 - val_regression_loss: 4.4978 - val_regression_mae: 1.3894
# Epoch 18/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 517us/step - classification_accuracy: 0.7002 - classification_loss: 0.7039 - loss: 5.1262 - regression_loss: 4.4223 - regression_mae: 1.3755 - val_classification_accuracy: 0.6935 - val_classification_loss: 0.7174 - val_loss: 5.1354 - val_regression_loss: 4.4178 - val_regression_mae: 1.3717
# Epoch 19/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 507us/step - classification_accuracy: 0.7014 - classification_loss: 0.7040 - loss: 5.0679 - regression_loss: 4.3639 - regression_mae: 1.3704 - val_classification_accuracy: 0.6950 - val_classification_loss: 0.7186 - val_loss: 5.1597 - val_regression_loss: 4.4409 - val_regression_mae: 1.3902
# Epoch 20/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 510us/step - classification_accuracy: 0.6997 - classification_loss: 0.7053 - loss: 5.0909 - regression_loss: 4.3856 - regression_mae: 1.3739 - val_classification_accuracy: 0.6960 - val_classification_loss: 0.7191 - val_loss: 5.1593 - val_regression_loss: 4.4401 - val_regression_mae: 1.3788
# Epoch 21/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 496us/step - classification_accuracy: 0.7018 - classification_loss: 0.7025 - loss: 5.0099 - regression_loss: 4.3075 - regression_mae: 1.3681 - val_classification_accuracy: 0.6935 - val_classification_loss: 0.7151 - val_loss: 5.2098 - val_regression_loss: 4.4945 - val_regression_mae: 1.3720
# Epoch 22/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 508us/step - classification_accuracy: 0.7015 - classification_loss: 0.6993 - loss: 5.0133 - regression_loss: 4.3140 - regression_mae: 1.3678 - val_classification_accuracy: 0.6964 - val_classification_loss: 0.7100 - val_loss: 5.2751 - val_regression_loss: 4.5649 - val_regression_mae: 1.4104
# Epoch 23/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 501us/step - classification_accuracy: 0.7017 - classification_loss: 0.7021 - loss: 5.0573 - regression_loss: 4.3552 - regression_mae: 1.3683 - val_classification_accuracy: 0.6966 - val_classification_loss: 0.7100 - val_loss: 5.1137 - val_regression_loss: 4.4036 - val_regression_mae: 1.3755
# Epoch 24/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 500us/step - classification_accuracy: 0.7031 - classification_loss: 0.6965 - loss: 5.0456 - regression_loss: 4.3491 - regression_mae: 1.3701 - val_classification_accuracy: 0.6943 - val_classification_loss: 0.7137 - val_loss: 5.1051 - val_regression_loss: 4.3912 - val_regression_mae: 1.3728
# Epoch 25/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 501us/step - classification_accuracy: 0.7015 - classification_loss: 0.7029 - loss: 5.0375 - regression_loss: 4.3345 - regression_mae: 1.3676 - val_classification_accuracy: 0.6969 - val_classification_loss: 0.7115 - val_loss: 5.1310 - val_regression_loss: 4.4193 - val_regression_mae: 1.3685
# Epoch 26/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 502us/step - classification_accuracy: 0.7010 - classification_loss: 0.7032 - loss: 4.9943 - regression_loss: 4.2911 - regression_mae: 1.3611 - val_classification_accuracy: 0.6946 - val_classification_loss: 0.7196 - val_loss: 5.1108 - val_regression_loss: 4.3910 - val_regression_mae: 1.3740
# Epoch 27/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 497us/step - classification_accuracy: 0.7036 - classification_loss: 0.6964 - loss: 5.0297 - regression_loss: 4.3333 - regression_mae: 1.3662 - val_classification_accuracy: 0.6931 - val_classification_loss: 0.7160 - val_loss: 5.1622 - val_regression_loss: 4.4460 - val_regression_mae: 1.3701
# Epoch 28/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 510us/step - classification_accuracy: 0.7037 - classification_loss: 0.6959 - loss: 4.9702 - regression_loss: 4.2743 - regression_mae: 1.3611 - val_classification_accuracy: 0.6982 - val_classification_loss: 0.7069 - val_loss: 5.1135 - val_regression_loss: 4.4064 - val_regression_mae: 1.3730
# Epoch 29/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 497us/step - classification_accuracy: 0.7042 - classification_loss: 0.6987 - loss: 5.0015 - regression_loss: 4.3028 - regression_mae: 1.3651 - val_classification_accuracy: 0.6963 - val_classification_loss: 0.7083 - val_loss: 5.1184 - val_regression_loss: 4.4099 - val_regression_mae: 1.3798
# Epoch 30/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 499us/step - classification_accuracy: 0.7036 - classification_loss: 0.6989 - loss: 4.9990 - regression_loss: 4.3001 - regression_mae: 1.3617 - val_classification_accuracy: 0.6968 - val_classification_loss: 0.7078 - val_loss: 5.0657 - val_regression_loss: 4.3577 - val_regression_mae: 1.3564
# Epoch 31/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 497us/step - classification_accuracy: 0.7031 - classification_loss: 0.6975 - loss: 4.9962 - regression_loss: 4.2987 - regression_mae: 1.3579 - val_classification_accuracy: 0.6967 - val_classification_loss: 0.7086 - val_loss: 5.1479 - val_regression_loss: 4.4391 - val_regression_mae: 1.3689
# Epoch 32/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 505us/step - classification_accuracy: 0.7034 - classification_loss: 0.6959 - loss: 4.9484 - regression_loss: 4.2526 - regression_mae: 1.3554 - val_classification_accuracy: 0.6956 - val_classification_loss: 0.7147 - val_loss: 5.2342 - val_regression_loss: 4.5193 - val_regression_mae: 1.4028
# Epoch 33/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 498us/step - classification_accuracy: 0.7030 - classification_loss: 0.6930 - loss: 4.9382 - regression_loss: 4.2452 - regression_mae: 1.3579 - val_classification_accuracy: 0.6845 - val_classification_loss: 0.7305 - val_loss: 5.2119 - val_regression_loss: 4.4811 - val_regression_mae: 1.4085
# Epoch 34/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 496us/step - classification_accuracy: 0.7043 - classification_loss: 0.6982 - loss: 4.9183 - regression_loss: 4.2201 - regression_mae: 1.3524 - val_classification_accuracy: 0.6937 - val_classification_loss: 0.7162 - val_loss: 5.2582 - val_regression_loss: 4.5418 - val_regression_mae: 1.4144
# Epoch 35/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 502us/step - classification_accuracy: 0.7036 - classification_loss: 0.7006 - loss: 4.9645 - regression_loss: 4.2639 - regression_mae: 1.3545 - val_classification_accuracy: 0.6885 - val_classification_loss: 0.7350 - val_loss: 5.1271 - val_regression_loss: 4.3919 - val_regression_mae: 1.3730
# Epoch 36/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 502us/step - classification_accuracy: 0.7014 - classification_loss: 0.6976 - loss: 4.9626 - regression_loss: 4.2650 - regression_mae: 1.3570 - val_classification_accuracy: 0.6787 - val_classification_loss: 0.7372 - val_loss: 5.1266 - val_regression_loss: 4.3892 - val_regression_mae: 1.3700
# Epoch 37/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 502us/step - classification_accuracy: 0.7034 - classification_loss: 0.6977 - loss: 4.8862 - regression_loss: 4.1885 - regression_mae: 1.3486 - val_classification_accuracy: 0.6979 - val_classification_loss: 0.7125 - val_loss: 5.1531 - val_regression_loss: 4.4404 - val_regression_mae: 1.3953
# Epoch 38/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 503us/step - classification_accuracy: 0.7042 - classification_loss: 0.6942 - loss: 4.9271 - regression_loss: 4.2329 - regression_mae: 1.3507 - val_classification_accuracy: 0.6943 - val_classification_loss: 0.7155 - val_loss: 5.0974 - val_regression_loss: 4.3816 - val_regression_mae: 1.3648
# Epoch 39/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 497us/step - classification_accuracy: 0.7023 - classification_loss: 0.6993 - loss: 4.9654 - regression_loss: 4.2661 - regression_mae: 1.3568 - val_classification_accuracy: 0.6908 - val_classification_loss: 0.7159 - val_loss: 5.1193 - val_regression_loss: 4.4031 - val_regression_mae: 1.3581
# Epoch 40/40
# 3288/3288 ━━━━━━━━━━━━━━━━━━━━ 2s 501us/step - classification_accuracy: 0.7012 - classification_loss: 0.6991 - loss: 4.9412 - regression_loss: 4.2422 - regression_mae: 1.3560 - val_classification_accuracy: 0.6951 - val_classification_loss: 0.7160 - val_loss: 5.1295 - val_regression_loss: 4.4134 - val_regression_mae: 1.3666

# %%
reg_preds, cat_preds = model.predict(X_test_scaled)

# Convert classification prediction from probabilities to class labels
cat_labels = np.argmax(cat_preds, axis=1)
# Out:
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step

# %%
import matplotlib.pyplot as plt

# Plot regression loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['regression_loss'], label='Train Regression Loss')
plt.plot(history.history['val_regression_loss'], label='Val Regression Loss')
plt.title('Regression Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()

# Plot classification accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['classification_accuracy'], label='Train Accuracy')
plt.plot(history.history['val_classification_accuracy'], label='Val Accuracy')
plt.title('Classification Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

target_names = y_reg.columns

plt.figure(figsize=(16, 12))

for i in range(3):
    # Use entire test set for metrics
    actual_all = y_reg_test.iloc[:, i].values
    predicted_all = reg_preds[:, i]
    
    r2 = r2_score(actual_all, predicted_all)
    mae = mean_absolute_error(actual_all, predicted_all)
    rmse = mean_squared_error(actual_all, predicted_all, squared=False)

    # Use first 100 for plotting
    actual_100 = actual_all[:100]
    predicted_100 = predicted_all[:100]
    
    sorted_idx = np.argsort(actual_100)
    actual_sorted = actual_100[sorted_idx]
    predicted_sorted = predicted_100[sorted_idx]

    # Subplot
    plt.subplot(2, 2, i + 1)
    plt.plot(actual_sorted, label='Actual', linewidth=2)
    plt.plot(predicted_sorted, label='Predicted', linestyle='--')
    plt.title(f"{target_names[i]}\nR²: {r2:.3f}  |  MAE: {mae:.2f}  |  RMSE: {rmse:.2f}")
    plt.xlabel('Sample Index (sorted by actual)')
    plt.ylabel(target_names[i])
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cat_true_labels = np.argmax(y_cat_test, axis=1)
conf_mat = confusion_matrix(cat_true_labels, cat_labels)

disp = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=['No', 'Light', 'Mod', 'Heavy'])
disp.plot(cmap='Blues')
plt.title("Rainfall Category - Confusion Matrix")
plt.show()

# %%
model.save("/Users/user/Desktop/DA332_course_project_weather_visualization/models/weather_predictor_model.keras")

# %%
import joblib

joblib.dump(scaler, "/Users/user/Desktop/DA332_course_project_weather_visualization/models/x_scaler.pkl")
# Out:
# ['/Users/user/Desktop/DA332_course_project_weather_visualization/models/x_scaler.pkl']

# %%
city = 'Mumbai'

# %%
import requests
import pandas as pd
import time

def get_historical_weather(latitude, longitude, start_date, end_date):
    """
    Fetches historical daily weather data for a given location and date range.
    Implements retry logic if the API rate limit is exceeded.
    Fetches: Max/Min Temperature, Rainfall, Max Wind Speed
    """
    base_url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
        "latitude": latitude,
        "longitude": longitude,
        "start_date": start_date,
        "end_date": end_date,
        "daily": "temperature_2m_max,temperature_2m_min,precipitation_sum,windspeed_10m_max",
        "timezone": "auto"
    }

    while True:
        try:
            response = requests.get(base_url, params=params)
            if response.status_code == 429:
                print("Rate limit exceeded. Waiting 60 seconds before retrying...")
                time.sleep(60)
                continue
            
            response.raise_for_status()
            data = response.json()

            daily_df = pd.DataFrame({
                "Date": pd.to_datetime(data["daily"]["time"]),
                "Max Temperature (°C)": data["daily"]["temperature_2m_max"],
                "Min Temperature (°C)": data["daily"]["temperature_2m_min"],
                "Total Rainfall (mm)": data["daily"]["precipitation_sum"],
                "Max Wind Speed (m/s)": data["daily"]["windspeed_10m_max"]
            })

            return daily_df

        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}. Retrying in 60 seconds...")
            time.sleep(60)

# %%
import requests
import pandas as pd
import time
from datetime import datetime, timedelta

def get_historical_weather(latitude, longitude):
    """
    Fetches 7 unique, non-NaN days of historical weather data going backward from today.
    Skips any days that contain missing data (NaNs).
    """
    base_url = "https://archive-api.open-meteo.com/v1/archive"
    collected_data = []
    collected_dates = set()
    current_day = datetime.today()

    while len(collected_dates) < 7:
        start_date = (current_day - timedelta(days=2)).strftime('%Y-%m-%d')
        end_date = (current_day - timedelta(days=1)).strftime('%Y-%m-%d')

        params = {
            "latitude": latitude,
            "longitude": longitude,
            "start_date": start_date,
            "end_date": end_date,
            "daily": "temperature_2m_max,temperature_2m_min,precipitation_sum,windspeed_10m_max",
            "timezone": "auto"
        }

        try:
            response = requests.get(base_url, params=params)
            if response.status_code == 429:
                print("Rate limit exceeded. Waiting 60 seconds before retrying...")
                time.sleep(60)
                continue

            response.raise_for_status()
            data = response.json()

            if "daily" in data and "time" in data["daily"]:
                for i, date_str in enumerate(data["daily"]["time"]):
                    row = {
                        "Date": pd.to_datetime(date_str),
                        "Max Temperature (°C)": data["daily"]["temperature_2m_max"][i],
                        "Min Temperature (°C)": data["daily"]["temperature_2m_min"][i],
                        "Total Rainfall (mm)": data["daily"]["precipitation_sum"][i],
                        "Max Wind Speed (m/s)": data["daily"]["windspeed_10m_max"][i]
                    }

                    # Skip if any NaNs are present
                    if pd.isna(list(row.values())).any():
                        continue

                    if row["Date"] not in collected_dates:
                        collected_data.append(row)
                        collected_dates.add(row["Date"])

            current_day -= timedelta(days=1)

        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}. Retrying in 60 seconds...")
            time.sleep(60)

    full_df = pd.DataFrame(collected_data).sort_values(by="Date").reset_index(drop=True)
    return full_df

# %%
lat, lon = get_lat_lon(city)

# %%
print(lat, lon)
# Out:
# 19.08157715 72.88662753964906

# %%
import numpy as np
import pandas as pd

def add_day_of_week_encoding(df):
    """Adds sin_day and cos_day columns based on the Date."""
    df = df.copy()
    df['day_of_week'] = df['Date'].dt.dayofweek  # Monday = 0, Sunday = 6
    df['sin_day'] = np.sin(2 * np.pi * df['day_of_week'] / 7)
    df['cos_day'] = np.cos(2 * np.pi * df['day_of_week'] / 7)
    return df


def create_single_lagged_tuple(df):
    """
    Create a single lagged feature vector using 7 days of data.
    Assumes df is sorted by date and contains exactly 7 rows.
    """
    if len(df) != 7:
        raise ValueError("DataFrame must contain exactly 7 rows")

    # Compute sin_day and cos_day for the most recent day (last row)
    last_day = df.iloc[-1]
    day_of_week = last_day['Date'].dayofweek
    sin_day = np.sin(2 * np.pi * day_of_week / 7)
    cos_day = np.cos(2 * np.pi * day_of_week / 7)

    # Flatten the past 7 days of features
    lagged_block = df[[
        "Max Temperature (°C)", 
        "Min Temperature (°C)", 
        "Total Rainfall (mm)", 
        "Max Wind Speed (m/s)"
    ]].values.flatten()

    # Combine into one feature vector
    feature_vector = np.concatenate([lagged_block, [sin_day, cos_day]])
    return feature_vector

# %%
X_lagged = create_single_lagged_tuple(daily_df)
X_lagged
# Out:
# array([33.1       , 25.8       ,  0.        , 15.4       , 32.5       ,
#        25.8       ,  0.        , 15.7       , 32.4       , 26.1       ,
#         0.        , 14.9       , 32.8       , 26.2       ,  0.        ,
#        15.9       , 33.1       , 25.4       ,  0.        , 14.5       ,
#        32.8       , 26.        ,  0.        , 15.3       , 34.4       ,
#        25.5       ,  0.        , 16.8       ,  0.78183148,  0.6234898 ])

# %%
X_lagged.shape
# Out:
# (30,)

# %%
X_sample_scaled = scaler.fit_transform(X_lagged.reshape(-1, 1))

# %%
X_sample_scaled = X_sample_scaled.reshape(1, -1)

# %%
X_sample_scaled.shape
# Out:
# (1, 30)

# %%
from tensorflow.keras.models import load_model
import joblib

# Load saved model and scaler
model = load_model("/Users/user/Desktop/DA332_course_project_weather_visualization/models/weather_predictor_model.keras")
scaler = joblib.load("/Users/user/Desktop/DA332_course_project_weather_visualization/models/x_scaler.pkl")
# Out:
# /Users/user/anaconda3/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 10 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
reg_output, class_output = model.predict(X_sample_scaled)

max_temp, min_temp, wind_speed = reg_output[0]

rainfall_class_probs = class_output[0]
rainfall_class = rainfall_class_probs.argmax()  # 0 → No rain, 1 → Light, 2 → Moderate, 3 → Heavy
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
# Ensure correct shape
if X_sample_scaled.shape != (1, 30):
    X_sample_scaled = X_sample_scaled.reshape(1, -1)

# Make prediction
reg_output, class_output = model.predict(X_sample_scaled)

# Parse regression output
max_temp, min_temp, wind_speed = reg_output[0]

# Parse classification output
rainfall_class_probs = class_output[0]
rainfall_class = rainfall_class_probs.argmax()

# Print results
rain_labels = ["No Rain", "Light Rain", "Moderate Rain", "Heavy Rain"]
print("Predicted Max Temp (°C):", round(max_temp, 2))
print("Predicted Min Temp (°C):", round(min_temp, 2))
print("Predicted Max Wind Speed (m/s):", round(wind_speed, 2))
print("Rainfall Category Prediction:", rain_labels[rainfall_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted Max Temp (°C): 42.56
# Predicted Min Temp (°C): 20.56
# Predicted Max Wind Speed (m/s): 19.14
# Rainfall Category Prediction: No Rain

# %%
def fetch_weather_for_date(latitude, longitude, date):
    base_url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
        "latitude": latitude,
        "longitude": longitude,
        "start_date": date,
        "end_date": date,
        "daily": "temperature_2m_max,temperature_2m_min,precipitation_sum,windspeed_10m_max",
        "timezone": "auto"
    }

    while True:
        try:
            response = requests.get(base_url, params=params)
            if response.status_code == 429:
                print("Rate limit hit. Waiting 60 seconds...")
                time.sleep(60)
                continue
            response.raise_for_status()
            data = response.json()

            if "daily" in data and "time" in data["daily"]:
                return pd.DataFrame({
                    "Date": pd.to_datetime(data["daily"]["time"]),
                    "Max Temperature (°C)": data["daily"]["temperature_2m_max"],
                    "Min Temperature (°C)": data["daily"]["temperature_2m_min"],
                    "Total Rainfall (mm)": data["daily"]["precipitation_sum"],
                    "Max Wind Speed (m/s)": data["daily"]["windspeed_10m_max"]
                })
            else:
                return None
        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}. Retrying...")
            time.sleep(60)


def rainfall_category_to_mm(category):
    if category == 0:
        return 0.0
    elif category == 1:
        return round(np.random.exponential(scale=1.5), 2) % 5
    elif category == 2:
        value = 5 + np.random.exponential(scale=3)
        return round(min(value, 19.99), 2)
    elif category == 3:
        value = 20 + np.random.exponential(scale=15)
        return round(min(value, 199.99), 2)


def create_single_lagged_tuple(df):
    if len(df) != 7:
        raise ValueError("Expected exactly 7 rows of input")

    last_day = df.iloc[-1]
    day_of_week = last_day['Date'].dayofweek
    sin_day = np.sin(2 * np.pi * day_of_week / 7)
    cos_day = np.cos(2 * np.pi * day_of_week / 7)

    lagged_block = df[[
        "Max Temperature (°C)", 
        "Min Temperature (°C)", 
        "Total Rainfall (mm)", 
        "Max Wind Speed (m/s)"
    ]].values.flatten()

    return np.concatenate([lagged_block, [sin_day, cos_day]])


from tensorflow.keras.models import load_model
import joblib
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

def rolling_weather_prediction(latitude, longitude, model_path, scaler_path, n_days):
    model = load_model(model_path, compile=False)
    scaler = joblib.load(scaler_path)

    df = get_historical_weather(latitude, longitude)
    print("Initial data:", df)

    history = []

    for step in range(n_days):
        # Prepare input features
        X_raw = create_single_lagged_tuple(df).reshape(1, -1)
        X_scaled = scaler.transform(X_raw)

        # Predict
        reg_output, class_output = model.predict(X_scaled, verbose=0)
        max_temp, min_temp, wind_speed = reg_output[0]

        # Rainfall prediction
        rainfall_class = np.argmax(class_output[0])
        rainfall_mm = rainfall_category_to_mm(rainfall_class)

        # Prediction date = today + step
        next_date = datetime.today().date() + timedelta(days=step)

        # Store result
        history.append({
            "Prediction Date": next_date,
            "Predicted Max Temp (°C)": round(max_temp, 2),
            "Predicted Min Temp (°C)": round(min_temp, 2),
            "Predicted Rainfall (mm)": round(rainfall_mm, 2),
            "Predicted Wind Speed (m/s)": round(wind_speed, 2),
            "Rainfall Category": ["No Rain", "Light Rain", "Moderate Rain", "Heavy Rain"][rainfall_class]
        })

        # Simulate next day in place of real API data
        simulated_row = {
            "Date": pd.to_datetime(next_date),
            "Max Temperature (°C)": max_temp,
            "Min Temperature (°C)": min_temp,
            "Total Rainfall (mm)": rainfall_mm,
            "Max Wind Speed (m/s)": wind_speed
        }

        df = pd.concat([df.iloc[1:], pd.DataFrame([simulated_row])], ignore_index=True)

    return pd.DataFrame(history)

# %%
pred_df = rolling_weather_prediction(lat, lon, "/Users/user/Desktop/DA332_course_project_weather_visualization/models/weather_predictor_model.keras", "/Users/user/Desktop/DA332_course_project_weather_visualization/models/x_scaler.pkl", 3)
# Out:
# Initial data:         Date  Max Temperature (°C)  Min Temperature (°C)  Total Rainfall (mm)  \
# 0 2025-04-16                  33.1                  25.8                  0.0
# 1 2025-04-17                  32.5                  25.8                  0.0
# 2 2025-04-18                  32.4                  26.1                  0.0
# 3 2025-04-19                  32.8                  26.2                  0.0
# 4 2025-04-20                  33.1                  25.4                  0.0
# 5 2025-04-21                  32.8                  26.0                  0.0
# 6 2025-04-22                  34.4                  25.5                  0.0
#
#    Max Wind Speed (m/s)
# 0                  15.4
# 1                  15.7
# 2                  14.9
# 3                  15.9
# 4                  14.5
# 5                  15.3
# 6                  16.8
# /Users/user/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/user/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Users/user/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
pred_df
# Out:
#   Prediction Date  Predicted Max Temp (°C)  Predicted Min Temp (°C)  \
# 0      2025-04-25                     30.6                     22.0
# 1      2025-04-26                     31.2                     23.5
# 2      2025-04-27                     30.5                     22.8
#
#    Predicted Rainfall (mm)  Predicted Wind Speed (m/s) Rainfall Category
# 0                      0.0                        17.2           No Rain
# 1                      0.0                        15.9           No Rain
# 2                      0.0                        12.9           No Rain

# %%
def round_prediction_df(df, decimal_places=2):
    """
    Rounds all float columns in the DataFrame to the specified number of decimal places.
    Leaves non-numeric columns (like dates or strings) untouched.
    """
    df_rounded = df.copy()
    for col in df_rounded.columns:
        if pd.api.types.is_float_dtype(df_rounded[col]):
            df_rounded[col] = df_rounded[col].round(decimal_places)
    return df_rounded

# %%
rounded_df = round_prediction_df(pred_df)
pd.set_option("display.precision", 1)
print(rounded_df)
# Out:
#   Prediction Date  Predicted Max Temp (°C)  Predicted Min Temp (°C)  \
# 0      2025-04-25                     30.6                     22.0
# 1      2025-04-26                     31.2                     23.5
# 2      2025-04-27                     30.5                     22.8
#
#    Predicted Rainfall (mm)  Predicted Wind Speed (m/s) Rainfall Category
# 0                      0.0                        17.2           No Rain
# 1                      0.0                        15.9           No Rain
# 2                      0.0                        12.9           No Rain

# %%
pred_df.dtypes
# Out:
# Prediction Date                object
# Predicted Max Temp (°C)       float32
# Predicted Min Temp (°C)       float32
# Predicted Rainfall (mm)       float64
# Predicted Wind Speed (m/s)    float32
# Rainfall Category              object
# dtype: object
